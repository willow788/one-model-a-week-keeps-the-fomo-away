# %% [markdown]
# <a href="https://colab.research.google.com/github/willow788/one-model-a-week-keeps-the-fomo-away/blob/main/objects.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
print('all assets are imported')
# Out:
# all assets are imported

# %%
#load the image
img = cv2.imread('/content/coin.png')

#convert the image to grayscale
grayed_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(grayed_img, cmap='gray')
plt.show()

# %%
#applying gausian blur to reduce the noise
grayed_img_blurred = cv2.GaussianBlur(grayed_img, (11, 11), 0)
plt.imshow(grayed_img_blurred, cmap='gray')
plt.show()

# %%
#usiing the canny algorithm to detect the edges
canny_img = cv2.Canny(grayed_img_blurred, 30, 150, 3)
plt.imshow(canny_img, cmap='gray')
plt.show()

# %%
#smoothening the edge
dilated_and_smoothed_img = cv2.dilate(canny_img, (1, 1), iterations= 0 )
plt.imshow(dilated_and_smoothed_img, cmap='gray')
plt.show()

# %%
#calculating the no of contours
(contour, hierarchy) = cv2.findContours(
    dilated_and_smoothed_img.copy(),
    cv2.RETR_EXTERNAL,
    cv2.CHAIN_APPROX_NONE
)
rgb_colored  = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.drawContours(rgb_colored, contour, -1, (0, 255, 0), 2)
plt.imshow(rgb_colored)

# %%
print('no of edges: ', len(contour))
# Out:
# no of edges:  5
