# %% [markdown]
# <a href="https://colab.research.google.com/github/willow788/one-model-a-week-keeps-the-fomo-away/blob/main/logisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torchvision.datasets as dsets
import torchvision.transforms as transforms
from torch.autograd import Variable

print('all assets imported!')
# Out:
# all assets imported!

# %%
#setting the batch size
batch_size = 64

train_dataset = dsets.MNIST(root = './data',
                            train= True,
                            transform=transforms.ToTensor(),
                            download=True)

test_dataset = dsets.MNIST(root = './data',
                           train= False,
                           transform=transforms.ToTensor(),
                           download=True)

# %%
#dataset loader
train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size= batch_size,
                                           shuffle= True)
test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                        batch_size = batch_size,
                                        shuffle = True)

# %%
#hyperparameters
input_size= 784
num_classes= 10
num_epochs= 5
batch_size= 100
learning_rate= 0.001

class logisticRegression(nn.Module):
  def __init__(self, input_size, num_classes):
    super(logisticRegression, self).__init__()
    self.linear = nn.Linear(input_size, num_classes)

  def forward(self, x):
    out = self.linear(x)
    return out

model = logisticRegression(input_size, num_classes)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

#training the model
for epoch in range(num_epochs):
  for i, (images, labels) in enumerate(train_loader):
    images = Variable(images.view(-1, 28*28))
    labels = Variable(labels)

    optimizer.zero_grad()
    output = model(images)
    loss = criterion(output, labels)
    loss.backward()
    optimizer.step()

    if (i+1) % 100 == 0:
      print('Epoch: [% d/% d], step: [% d/ % d], loss: %.4f'
      %(epoch + 1, num_epochs, i +1,
        len(train_dataset) // batch_size, loss.item()))
# Out:
# Epoch: [ 1/ 5], step: [ 100/  600], loss: 2.2250
# Epoch: [ 1/ 5], step: [ 200/  600], loss: 2.0901
# Epoch: [ 1/ 5], step: [ 300/  600], loss: 1.9870
# Epoch: [ 1/ 5], step: [ 400/  600], loss: 1.9074
# Epoch: [ 1/ 5], step: [ 500/  600], loss: 1.8332
# Epoch: [ 1/ 5], step: [ 600/  600], loss: 1.8304
# Epoch: [ 1/ 5], step: [ 700/  600], loss: 1.7291
# Epoch: [ 1/ 5], step: [ 800/  600], loss: 1.6546
# Epoch: [ 1/ 5], step: [ 900/  600], loss: 1.6209
# Epoch: [ 2/ 5], step: [ 100/  600], loss: 1.5143
# Epoch: [ 2/ 5], step: [ 200/  600], loss: 1.3913
# Epoch: [ 2/ 5], step: [ 300/  600], loss: 1.4578
# Epoch: [ 2/ 5], step: [ 400/  600], loss: 1.4026
# Epoch: [ 2/ 5], step: [ 500/  600], loss: 1.3134
# Epoch: [ 2/ 5], step: [ 600/  600], loss: 1.3160
# Epoch: [ 2/ 5], step: [ 700/  600], loss: 1.1867
# Epoch: [ 2/ 5], step: [ 800/  600], loss: 1.1724
# Epoch: [ 2/ 5], step: [ 900/  600], loss: 1.2494
# Epoch: [ 3/ 5], step: [ 100/  600], loss: 1.0792
# ...

# %%
# Test the Model
correct = 0
total = 0
for images, labels in test_loader:
    images = Variable(images.view(-1, 28 * 28))
    outputs = model(images)
    _, predicted = torch.max(outputs.data, 1)
    total += labels.size(0)
    correct += (predicted == labels).sum()

print('Accuracy of the model on the 10000 test images: % d %%' % (
            100 * correct / total))
# Out:
# Accuracy of the model on the 10000 test images:  84 %
